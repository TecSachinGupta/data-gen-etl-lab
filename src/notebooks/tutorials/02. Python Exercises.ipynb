# %% [markdown]
# # Common Codes

# %%
# Importing all the required libraries
import datetime
import time
import os
import json
# import sys
import pandas as pd
# import numpy as np
import logging
import requests
import traceback

import uuid
from dataclasses import dataclass, field
import yfinance as yahoo_finance
import random

import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders

# %%
# Global variables or constants
INPUT_PATH = "/data/workspace_files/input/"
OUTPUT_PATH = "/data/workspace_files/output/"

MAIL_SERVER = "aaa.com"
MAIL_PORT = 0
SENDER_ID = "xyz@em.com"
RECEIVER_IDS = ("abc@em.com", "")

# %%
SIMPLE_EMAIL_MESSAGE = """
<html>
    <h1>Test mail</h1>
    <p>This is a Test mail</p>
</html>
"""

# %%
# configuring the logger to print logs
log_format1 = '%(asctime)s [%(levelname)-8s] <PID %(process)d:%(processName)s> %(name)s.%(funcName)s: %(message)s'
log_format2 = '%(asctime)s [%(levelname)-8s] %(name)s.%(funcName)s: %(message)s'
log_format3 = '%(asctime)s [%(levelname)-8s] [%(processName)s] %(name)s: %(message)s'

formatter = logging.Formatter(log_format3, datefmt='%d-%b-%Y %H:%M:%S')

console = logging.StreamHandler()
console.setFormatter(formatter)

file_handler = logging.FileHandler(OUTPUT_PATH + '/logs/stdout.log', "a")
file_handler.setFormatter(formatter)

logger = logging.getLogger("Python Exercises")

logger.handlers.clear()

logger.addHandler(console)
logger.addHandler(file_handler)

logger.setLevel(logging.INFO)

# %% [markdown]
# ### Generic Functions

# %%
def get_file_paths(src, extension=None, mindepth=1, maxdepth=float('inf')):
    """

Arguments:

Returns:
    """
    rootdir = os.path.normcase(src)
    file_paths = []
    root_depth = rootdir.rstrip(os.path.sep).count(os.path.sep) - 1
    for dirpath, dirs, files in os.walk(rootdir):
        depth = dirpath.count(os.path.sep) - root_depth
        if mindepth <= depth <= maxdepth:
            for filename in files:
                if extension is None:
                    file_paths.append(os.path.join(dirpath, filename))
                if os.path.splitext(filename)[1] == extension:
                    file_paths.append(os.path.join(dirpath, filename))
        elif depth > maxdepth:
            del dirs[:]
    return file_paths

# %%
def get_file_names(paths):
    """

Arguments:

Returns:
    """
    urls = []
    if type(paths) is str:
        urls.append(paths)
    if type(paths) is list:
        urls = paths

    file_names = [url.split(os.path.sep)[-1] for url in urls]

    return file_names

# %%
def download_file(src, dest):
    """
Function to dowload file(s) to a specified location
Returns a dictionary object stating details like source, destination, started date time, end date time and timetaken.
Arguments:
src - Location from which file needs to be downloaded
dest - Location at which file needs to be saved
Returns:
log - a dictionary object having all the details regarding the file download
    """
    log = {
        "source": src,
        "destination": dest,
        "started_on": datetime.datetime.now(),
        "completed_on": None,
        "time_taken": -1,
        "status": "Failed",
        "description": "UnKnown"
    }
    start = time.perf_counter()
    # noinspection PyBroadException
    try:
        response = requests.get(src)
        open(f"{dest}", "wb").write(response.content)
        log["status"] = "Successful".upper()
        log["description"] = "File is successfully dowloaded."
    except Exception as e:
        log["status"] = "Failed".upper()
        log["description"] = traceback.format_exc()

    end = time.perf_counter()
    log["time_taken"] = (end - start)
    log["completed_on"] = datetime.datetime.now()

    return log

# %%
def flatten_json(y):
    """

Arguments:

Returns:
    """
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
def send_email(mail_from=SENDER_ID,
               mail_to=RECEIVER_IDS,
               subject=None,
               message_text=None,
               file=None
               ):
    mail_sent = False
    try:
        message = MIMEMultipart("alternative")
        message["Subject"] = subject
        message["From"] = mail_from
        message["To"] = ", ".join(mail_to)
        message.attach(MIMEText(message_text, 'html'))
        if file is not None:
            part = MIMEBase('application', "octet-stream")
            part.set_payload(open(file, "rb").read())
            encoders.encode_base64(part)
            _, tail = os.path.split(file)
            part.add_header('Content-Disposition',
                            'attachment; filename={}'.format(str(tail)))
            message.attach(part)
        print("Message is : \n", message.as_string())
        smtp = smtplib.SMTP(MAIL_SERVER, MAIL_PORT)
        smtp.sendmail(mail_from, mail_to, message.as_string())
        mail_sent = True
        smtp.quit()
    except Exception as e:
        print(e)
    return mail_sent

# %%
def profile_data(df:pd.DataFrame):
    """
Type inference: detect the types of columns in a data frame.
Essentials: type, unique values, missing values
Quantile statistics like minimum value, Q1, median, Q3, maximum, range, inter-quartile range
Descriptive statistics like mean, mode, standard deviation, sum, median absolute deviation, coefficient of variation, kurtosis, skewness
Most frequent values
    """
    column_name_final = ["column_name", "data_type", "count", "uniqueness", "missing", "min", "max", "q1", "q25", "q50",
                         "q75", "q95", "mean", "mode", "std_dev", "sum", "kurtosis", "skewness", "top_5_values",
                         "most_freq_values"
                         ]
    print(column_name_final)
    pass

# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## Objective – Data Analysis
#
#
# ### Tasks
# 1. Diamond Prices
#
#    Diamonds are divided into five impurity types based on the structure of their carbon atoms. The [Diamonds dataset](https://www.kaggle.com/shivam2503/diamonds) from Kaggle gives you even more info — cut, clarity, color, and price. Develop your data visualization skills on it with some exploratory data analysis.
# 2. Age of Abalone Shells
#
#     This is a unique [dataset from zoology](https://www.kaggle.com/rodolfomendes/abalone-dataset). Abalone shells are miracles of nature, and you can determine their age by counting the circles inside their shells. Can you determine the age of Abalone shells with Python data analysis skills?
#
#
# ### Inputs
#
# ### Outputs

# %% [markdown]
# ### Task 1: – Diamond Data

# %%
def diamond_data_exploration():
    diamond_df = pd.read_csv(INPUT_PATH + "diamonds.csv")
    diamond_df = diamond_df.rename(columns={"Unnamed: 0": "id"})
    return diamond_df

# %%
diamond_df.dtypes

# %%
diamond_df

# %%
diamond_df.describe()

# %%
diamond_df.groupby(by=["cut"]).count().reset_index()

# %%
diamond_df.groupby(by=["clarity"]).count().reset_index()

# %%
diamond_df.groupby(by=["color"]).count().reset_index()

# %% [markdown]
# ### Task 2: – Abalone Age data

# %%
abalone_df = pd.read_csv(INPUT_PATH + "abalone.csv")

# %%
abalone_df.dtypes

# %%
abalone_df

# %%
abalone_df.groupby("Rings").count().reset_index()

# %% [markdown]
# # Exercise 2

# %% [markdown]
# ## Objective – Web Scraping
#
#
# ### Tasks
#
#
# ### Inputs
#
# ### Outputs

# %%
from typing import List, Optional

# %%
@dataclass
class Links:
    type: Optional[str]
    url: str
    language: Optional[str]

# %%
@dataclass
class Chapter:
    number: int
    title: str
    status: str
    released_on: datetime.datetime
    modified_on: datetime.datetime
    links: List[Links]

# %%
@dataclass
class Episode:
    number: int
    title: str
    description: str
    status: str
    released_on: datetime.datetime
    modified_on: datetime.datetime
    links: List[Links]

# %%
@dataclass
class Season:
    number: int
    title: str
    description: str
    status: str
    modified_on: datetime.datetime
    episodes: List[Episode]

# %%
@dataclass
class Volume:
    number: int
    title: str
    status: str
    modified_on: datetime.datetime
    chapters: List[Chapter]

# %%
@dataclass
class Video:
    number: int
    title: str
    status: str
    modified_on: datetime.datetime
    links: List[Season]

# %%
@dataclass
class Catalog:
    name: Optional[str]
    description: Optional[str]
    country_of_origin: Optional[str]
    genres: Optional[List[str]]
    tags: Optional[List[str]]
    other_names: Optional[List[str]]
    links: Optional[List[Links]]
    novels: Optional[List[Volume]]
    manga: Optional[List[Volume]]
    anime: Optional[List[Video]]
    id: str = field(default_factory = lambda: str(uuid.uuid4()))
    released_on: datetime.datetime = field(default_factory = lambda: datetime.datetime.now())
    created_on: datetime.datetime= field(default_factory = lambda : datetime.datetime.now())

# %%
catalog_json = {
    "id": str(uuid.uuid4()),
    "name": None,
    "description": "",
    
}

# %%
def build_catalog_data():
    pass

# %% [markdown]
# # Exercise 3

# %% [markdown]
# ## Objective – Stock Price Prediction
#
#
# ### Tasks
#
#
# ### Inputs
#
# ### Outputs

# %%
def get_symbols_from_csv():
    symobls_df = pd.read_csv(INPUT_PATH + "nasdaq_symbols_data.csv")
    symobls_df = symobls_df.astype({"Symbol": str, "Name": str})
    symbols = symobls_df['Symbol']
    return symbols

# %%
# noinspection PyBroadException
def get_stock_data(symbols):
    # download or scrape data from the url or API or webpage
    stock_info = {}
    stock_data = None
    failed_symbols = []
    file_name = "stocks_data_{index}.csv"
    file_index = 1
    file_path = OUTPUT_PATH + file_name
    for index, symbol in enumerate(symbols):
        try:
            ticker = yahoo_finance.Ticker(symbol)
            stock_info[symbol] = ticker.info
            # Let us  get historical stock prices for specified Symbol or Ticker covering the past few years.
            # max-> maximum number of daily prices available
            # Valid options are 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y and ytd.
            ticker_history = ticker.history(period="max")
            ticker_history.insert(0, "symbol", symbol)
            if stock_data is None:
                stock_data = ticker_history.copy(deep=True)
                ticker_history.to_csv(file_path.format(index = file_index), header = True, mode='w', index = True, index_label = "date_time")
            else:
                #stock_data = pd.concat([stock_data, ticker_history], ignore_index=False)
                ticker_history.to_csv(file_path.format(index = file_index), header = False, mode='a', index = True, index_label = "date_time")

            logger.info({"ticker_index":index, "ticker": symbol, "status": "SUCCESSFUL", "description": "Data written to file " + file_name.format(index = file_index)})
            
            if os.path.getsize(file_path.format(index = file_index)) >= 246415360: # 268435456 to 246415360 i.e. 256MiB to 235MiB
                file_index += 1
                stock_data = None
        except Exception:
            logger.error({"ticker_index":index, "ticker": symbol, "status": "FAILED", "description": traceback.format_exc()})
            failed_symbols.append(symbol)
        #time.sleep(1)
    with open(OUTPUT_PATH + "stock_info.json", "w", encoding='utf-8') as f:
        json.dump(stock_info, f)
    logger.info("List of failed symbols are : "+ str(failed_symbols))
    return stock_data

# %%
def train_stock_prediction_model():
    pass

# %%
tickers = get_symbols_from_csv()
logger.info("Total Symbols present are: " + str(len(tickers)))
get_stock_data(tickers)
#stock_data_df = get_stock_data(tickers)
#stock_data_df.to_csv(OUTPUT_PATH + "stocks_data_1.csv", mode='w', index = True, index_label = "date_time")
# Out:
# 06-Sep-2023 10:32:55 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GTY', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:32:58 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GUG', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:02 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GURE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:06 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GUT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:09 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GUT^C', 'status': 'FAILED', 'description': 'Traceback (most recent call last):\n  File "<ipython-input-12-1beaad720e94>", line 13, in get_stock_data\n    stock_info[symbol] = ticker.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/ticker.py", line 142, in info\n    return self.get_info()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/base.py", line 1678, in get_info\n    data = self._quote.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 571, in info\n    self._fetch(self.proxy)\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 600, in _fetch\n    result = self._data.get_raw_json(\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/data.py", line 75, in get_raw_json\n    response.raise_for_status()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/requests/models.py", line 1021, in raise_for_status\n    raise HTTPError(http_error_msg, response=self)\nrequests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/GUT%5EC?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true\n'}
# 06-Sep-2023 10:33:10 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GVA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:13 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GVP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:17 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GWAV', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:22 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GWH', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:24 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GWRE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:28 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GWRS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:33 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GWW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:36 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GXO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:40 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'GYRO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:44 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'H', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:48 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:52 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HAE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:33:56 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HAFC', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:00 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HAIA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:04 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HAIAU', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:08 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HAIAW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:12 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HAIN', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:17 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HAL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:20 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HALL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:24 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HALO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:28 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HARP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:33 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HAS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:36 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HASI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:41 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HAYN', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:45 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HAYW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:50 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HBAN', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:53 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HBANL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:34:58 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HBANM', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:02 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HBANP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:06 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HBB', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:10 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HBCP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:15 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HBI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:19 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HBIO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:23 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HBM', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:28 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HBNC', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:32 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HBT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:36 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:41 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCAT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:45 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCC', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:49 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCCI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:54 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCDI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:35:58 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCDIP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:03 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCDIW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:07 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCDIZ', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:12 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:16 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCKT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:20 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCM', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:25 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCMA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:29 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCMAW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:34 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:39 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCSG', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:43 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCTI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:47 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCVI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:52 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCVIU', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:36:56 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCVIW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:01 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCWB', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:05 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HCXY', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:10 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HD', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:14 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HDB', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:19 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HDSN', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:24 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:28 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HEAR', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:33 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HEES', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:38 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HEI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:42 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HEI/A', 'status': 'FAILED', 'description': 'Traceback (most recent call last):\n  File "<ipython-input-12-1beaad720e94>", line 13, in get_stock_data\n    stock_info[symbol] = ticker.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/ticker.py", line 142, in info\n    return self.get_info()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/base.py", line 1678, in get_info\n    data = self._quote.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 571, in info\n    self._fetch(self.proxy)\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 600, in _fetch\n    result = self._data.get_raw_json(\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/data.py", line 75, in get_raw_json\n    response.raise_for_status()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/requests/models.py", line 1021, in raise_for_status\n    raise HTTPError(http_error_msg, response=self)\nrequests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/HEI/A?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true\n'}
# 06-Sep-2023 10:37:42 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HELE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:47 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HEP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:51 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HEPA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:37:56 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HEPS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:01 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HEQ', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:06 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HES', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:11 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HESM', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:16 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HFBL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:20 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HFFG', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:25 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HFRO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:30 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HFRO^A', 'status': 'FAILED', 'description': 'Traceback (most recent call last):\n  File "<ipython-input-12-1beaad720e94>", line 13, in get_stock_data\n    stock_info[symbol] = ticker.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/ticker.py", line 142, in info\n    return self.get_info()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/base.py", line 1678, in get_info\n    data = self._quote.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 571, in info\n    self._fetch(self.proxy)\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 600, in _fetch\n    result = self._data.get_raw_json(\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/data.py", line 75, in get_raw_json\n    response.raise_for_status()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/requests/models.py", line 1021, in raise_for_status\n    raise HTTPError(http_error_msg, response=self)\nrequests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/HFRO%5EA?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true\n'}
# 06-Sep-2023 10:38:30 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HFWA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:35 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HGBL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:40 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HGLB', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:45 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HGTY', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:50 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HGV', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:54 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HHGC', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:38:59 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HHGCR', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:39:04 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HHGCW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:39:09 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HHH', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:39:14 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HHLA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:39:19 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HHRS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:39:24 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HHRSW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:39:29 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HHS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:39:34 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:39:39 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIBB', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:39:45 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:39:49 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIFS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:39:54 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIG', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:39:59 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIG^G', 'status': 'FAILED', 'description': 'Traceback (most recent call last):\n  File "<ipython-input-12-1beaad720e94>", line 13, in get_stock_data\n    stock_info[symbol] = ticker.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/ticker.py", line 142, in info\n    return self.get_info()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/base.py", line 1678, in get_info\n    data = self._quote.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 571, in info\n    self._fetch(self.proxy)\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 600, in _fetch\n    result = self._data.get_raw_json(\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/data.py", line 75, in get_raw_json\n    response.raise_for_status()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/requests/models.py", line 1021, in raise_for_status\n    raise HTTPError(http_error_msg, response=self)\nrequests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/HIG%5EG?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true\n'}
# 06-Sep-2023 10:40:00 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIHO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:40:04 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HII', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:40:09 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HILS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:40:15 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIMS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:40:20 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIMX', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:40:25 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:40:30 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIPO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:40:35 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HITI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:40:41 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIVE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:40:46 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:40:51 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HIX', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:40:56 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HKD', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:41:01 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HKIT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:41:07 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:41:11 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HL^B', 'status': 'FAILED', 'description': 'Traceback (most recent call last):\n  File "<ipython-input-12-1beaad720e94>", line 13, in get_stock_data\n    stock_info[symbol] = ticker.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/ticker.py", line 142, in info\n    return self.get_info()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/base.py", line 1678, in get_info\n    data = self._quote.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 571, in info\n    self._fetch(self.proxy)\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 600, in _fetch\n    result = self._data.get_raw_json(\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/data.py", line 75, in get_raw_json\n    response.raise_for_status()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/requests/models.py", line 1021, in raise_for_status\n    raise HTTPError(http_error_msg, response=self)\nrequests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/HL%5EB?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true\n'}
# 06-Sep-2023 10:41:12 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLF', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:41:17 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLGN', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:41:22 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:41:28 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLIO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:41:33 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLIT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:41:39 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLLY', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:41:44 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLMN', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:41:49 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLN', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:41:55 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLNE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:42:00 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:42:05 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:42:11 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLTH', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:42:17 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLVX', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:42:22 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HLX', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:42:27 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HMC', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:42:33 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HMN', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:42:38 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HMNF', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:42:43 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HMST', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:42:49 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HMY', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:42:55 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HNI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:43:00 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HNNA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:43:06 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HNNAZ', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:43:11 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HNRA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:43:17 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HNRG', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:43:22 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HNST', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:43:28 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HNVR', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:43:34 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HNW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:43:40 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOFT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:43:45 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOFV', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:43:51 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOFVW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:43:57 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOG', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:44:02 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOLI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:44:08 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOLO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:44:15 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOLOW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:44:20 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOLX', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:44:25 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOMB', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:44:32 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HON', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:44:37 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HONE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:44:43 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOOD', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:44:49 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOOK', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:44:55 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOPE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:45:00 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOTH', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:45:06 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOUR', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:45:12 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOUS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:45:18 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOV', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:45:24 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOVNP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:45:30 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HOWL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:45:36 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:45:42 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HPCO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:45:48 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HPE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:45:54 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HPF', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:46:00 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HPI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:46:06 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HPK', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:46:12 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HPKEW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:46:18 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HPLT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:46:24 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HPLTW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:46:30 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HPP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:46:36 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HPP^C', 'status': 'FAILED', 'description': 'Traceback (most recent call last):\n  File "<ipython-input-12-1beaad720e94>", line 13, in get_stock_data\n    stock_info[symbol] = ticker.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/ticker.py", line 142, in info\n    return self.get_info()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/base.py", line 1678, in get_info\n    data = self._quote.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 571, in info\n    self._fetch(self.proxy)\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 600, in _fetch\n    result = self._data.get_raw_json(\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/data.py", line 75, in get_raw_json\n    response.raise_for_status()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/requests/models.py", line 1021, in raise_for_status\n    raise HTTPError(http_error_msg, response=self)\nrequests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/HPP%5EC?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true\n'}
# 06-Sep-2023 10:46:37 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HPQ', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:46:43 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HPS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:46:49 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HQH', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:46:55 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HQI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:47:01 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HQL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:47:07 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HQY', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:47:14 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HR', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:47:20 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HRB', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:47:26 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HRI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:47:33 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HRL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:47:39 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HRMY', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:47:45 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HROW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:47:51 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HROWL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:47:58 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HROWM', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:48:04 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HRT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:48:11 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HRTG', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:48:17 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HRTX', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:48:23 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HRYU', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:48:30 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HRZN', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:48:36 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSAI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:48:43 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSBC', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:48:49 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSCS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:48:56 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSCSW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:49:02 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSDT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:49:09 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSHP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:49:16 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSIC', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:49:22 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSII', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:49:28 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSON', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:49:35 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSPO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:49:41 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSPOR', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:49:48 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSPOW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:49:55 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HST', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:50:01 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSTM', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:50:08 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSTO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:50:15 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HSY', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:50:21 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:50:27 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HT^C', 'status': 'FAILED', 'description': 'Traceback (most recent call last):\n  File "<ipython-input-12-1beaad720e94>", line 13, in get_stock_data\n    stock_info[symbol] = ticker.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/ticker.py", line 142, in info\n    return self.get_info()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/base.py", line 1678, in get_info\n    data = self._quote.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 571, in info\n    self._fetch(self.proxy)\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 600, in _fetch\n    result = self._data.get_raw_json(\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/data.py", line 75, in get_raw_json\n    response.raise_for_status()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/requests/models.py", line 1021, in raise_for_status\n    raise HTTPError(http_error_msg, response=self)\nrequests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/HT%5EC?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true\n'}
# 06-Sep-2023 10:50:27 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HT^D', 'status': 'FAILED', 'description': 'Traceback (most recent call last):\n  File "<ipython-input-12-1beaad720e94>", line 13, in get_stock_data\n    stock_info[symbol] = ticker.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/ticker.py", line 142, in info\n    return self.get_info()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/base.py", line 1678, in get_info\n    data = self._quote.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 571, in info\n    self._fetch(self.proxy)\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 600, in _fetch\n    result = self._data.get_raw_json(\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/data.py", line 75, in get_raw_json\n    response.raise_for_status()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/requests/models.py", line 1021, in raise_for_status\n    raise HTTPError(http_error_msg, response=self)\nrequests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/HT%5ED?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true\n'}
# 06-Sep-2023 10:50:27 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HT^E', 'status': 'FAILED', 'description': 'Traceback (most recent call last):\n  File "<ipython-input-12-1beaad720e94>", line 13, in get_stock_data\n    stock_info[symbol] = ticker.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/ticker.py", line 142, in info\n    return self.get_info()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/base.py", line 1678, in get_info\n    data = self._quote.info\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 571, in info\n    self._fetch(self.proxy)\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/scrapers/quote.py", line 600, in _fetch\n    result = self._data.get_raw_json(\n  File "/opt/python/envs/default/lib/python3.8/site-packages/yfinance/data.py", line 75, in get_raw_json\n    response.raise_for_status()\n  File "/opt/python/envs/default/lib/python3.8/site-packages/requests/models.py", line 1021, in raise_for_status\n    raise HTTPError(http_error_msg, response=self)\nrequests.exceptions.HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v6/finance/quoteSummary/HT%5EE?modules=financialData&modules=quoteType&modules=defaultKeyStatistics&modules=assetProfile&modules=summaryDetail&ssl=true\n'}
# 06-Sep-2023 10:50:28 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTBI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:50:35 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTBK', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:50:41 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTCR', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:50:48 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTD', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:50:54 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTFB', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:51:01 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTFC', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:51:08 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTGC', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:51:15 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTH', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:51:22 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTHT', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:51:28 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTIA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:51:35 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTIBP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:51:42 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTLD', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:51:49 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTLF', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# 06-Sep-2023 10:51:56 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'HTLFP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_5.csv'}
# ...
# 06-Sep-2023 15:37:40 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'YUMC', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:37:47 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'YY', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:37:55 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'Z', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:38:03 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZAPP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:38:11 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZAPPW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:38:19 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZBH', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:38:27 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZBRA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:38:34 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZCMD', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:38:43 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZD', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:38:50 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZDGE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:38:58 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZENV', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:39:06 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZEPP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:39:14 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZETA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:39:22 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZEUS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:39:30 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZEV', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:39:38 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZFOX', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:39:46 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZG', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:39:54 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZGN', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:40:02 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZH', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:40:10 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:40:18 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZIM', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:40:26 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZIMV', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:40:34 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZION', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:40:42 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZIONL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:40:50 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZIONO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:40:58 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZIONP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:41:06 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZIP', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:41:14 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZIVO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:41:22 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZIVOW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:41:30 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZJYL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:41:38 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZKIN', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:41:47 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZLAB', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:41:54 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZLS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:42:02 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZM', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:42:10 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZNTL', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:42:18 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZOM', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:42:27 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:42:35 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZTEK', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:42:43 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZTO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:42:51 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZTR', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:42:59 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZTS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:43:08 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZUMZ', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:43:15 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZUO', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:43:24 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZURA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:43:32 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZURAW', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:43:40 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZVIA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:43:48 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZVRA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:43:56 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZVSA', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:44:05 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZWS', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:44:13 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZYME', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:44:21 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZYNE', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:44:30 [INFO    ] [MainProcess] Python Exercises: {'ticker': 'ZYXI', 'status': 'SUCCESSFUL', 'description': 'Data written to file stocks_data_11.csv'}
# 06-Sep-2023 15:44:40 [INFO    ] [MainProcess] Python Exercises: List of failed symbols are : ['AAIC^B', 'AAIC^C', 'AAM^A', 'AAM^B', 'ABR^D', 'ABR^E', 'ABR^F', 'ACP^A', 'ACR^C', 'ACR^D', 'ADC^A', 'AEL^A', 'AEL^B', 'AGM^C', 'AGM^D', 'AGM^E', 'AGM^F', 'AGM^G', 'AHH^A', 'AHL^C', 'AHL^D', 'AHL^E', 'AHT^D', 'AHT^F', 'AHT^G', 'AHT^H', 'AHT^I', 'AIG^A', 'AKO/A', 'AKO/B', 'AL^A', 'ALL^B', 'ALL^H', 'ALL^I', 'ALL^J', 'ALTG^A', 'AMH^G', 'AMH^H', 'APO^A', 'ARGO^A', 'ARR^C', 'ASB^E', 'ASB^F', 'ATCO^D', 'ATCO^H', 'ATCO^I', 'ATH^A', 'ATH^B', 'ATH^C', 'ATH^D', 'ATH^E', 'AUB^A', 'AULT^D', 'AXS^E', 'BAC^B', 'BAC^E', 'BAC^K', 'BAC^L
td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2021-11-01 00:00:00-04:00</th>
#       <td>UDMY</td>
#       <td>28.000000</td>
#       <td>29.690001</td>
#       <td>26.110001</td>
#       <td>29.219999</td>
#       <td>2189400</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2021-11-02 00:00:00-04:00</th>
#       <td>UDMY</td>
#       <td>29.219999</td>
#       <td>29.590000</td>
#       <td>27.705000</td>
#       <td>29.459999</td>
#       <td>1371000</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2021-11-03 00:00:00-04:00</th>
#       <td>UDMY</td>
#       <td>29.590000</td>
#       <td>29.990000</td>
#       <td>27.129999</td>
#       <td>28.600000</td>
#       <td>1338900</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2021-11-04 00:00:00-04:00</th>
#       <td>UDMY</td>
#       <td>28.980000</td>
#       <td>29.030001</td>
#       <td>27.219999</td>
#       <td>27.379999</td>
#       <td>2029700</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>2023-08-30 00:00:00-04:00</th>
#       <td>UDMY</td>
#       <td>10.150000</td>
#       <td>10.480000</td>
#       <td>10.145000</td>
#       <td>10.450000</td>
#       <td>390700</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2023-08-31 00:00:00-04:00</th>
#       <td>UDMY</td>
#       <td>10.490000</td>
#       <td>10.670000</td>
#       <td>10.330000</td>
#       <td>10.360000</td>
#       <td>477400</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2023-09-01 00:00:00-04:00</th>
#       <td>UDMY</td>
#       <td>10.500000</td>
#       <td>10.630000</td>
#       <td>10.205000</td>
#       <td>10.230000</td>
#       <td>434700</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2023-09-05 00:00:00-04:00</th>
#       <td>UDMY</td>
#       <td>10.210000</td>
#       <td>10.720000</td>
#       <td>10.105000</td>
#       <td>10.580000</td>
#       <td>725700</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2023-09-06 00:00:00-04:00</th>
#       <td>UDMY</td>
#       <td>10.610000</td>
#       <td>10.680000</td>
#       <td>10.105000</td>
#       <td>10.105000</td>
#       <td>82433</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
# <p>465 rows × 8 columns</p>
# </div>

# %% [markdown]
# # Exercise 4

# %% [markdown]
# ## Objective – Log file Parsing
#
# ### Tasks
#
#
# ### Inputs
#
# ### Outputs

# %%
json_data = []

# %%
with open(OUTPUT_PATH + "/logs/stdout_01.log", "r") as f:
    i = 0
    for line in f.readlines():
        if i==0:
            i += 1
            continue
        #print(line)
        #print(line[64:])
        if "SUCCESSFUL" in line:
            json_data.append(json.loads(line[64:].replace("'", '"')))

# %%
json_data
# Out:
# [{'ticker': 'A',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'A',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AA',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AACG',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AACI',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AACIW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AACT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AADI',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAIC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'A',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AA',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AACG',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AACI',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AACIW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AACT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AADI',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAIC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAIN',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAL',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAMC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAME',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAN',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAOI',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAON',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAP',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAPL',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AAU',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AB',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABBV',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABCB',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABCL',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABCM',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABEO',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABEV',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABG',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABIO',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABL',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABLLW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABLV',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABLVW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABM',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABNB',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABOS',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABR',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABSI',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABUS',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ABVC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACA',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACAB',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACABW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACACU',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACACW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACAD',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACAQ',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACAX',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACAXR',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACAXU',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACAXW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACB',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACBA',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACBAW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACCD',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACCO',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACDC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACDCW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACEL',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACER',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACET',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACGL',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACGLN',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACGLO',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACHC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACHL',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACHR',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACHV',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACI',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACIC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACIU',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACIW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACLS',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACLX',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACM',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACMR',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACN',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACNB',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACNT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACON',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACONW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACOR',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACP',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACR',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACRE',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACRO',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACRS',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACRV',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACRX',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACST',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACTG',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACU',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACV',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACVA',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ACXP',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADAG',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADAP',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADBE',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADCT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADD',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADEA',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADER',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADERW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADES',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADEX',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADI',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADIL',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADM',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADMA',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADMP',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADN',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADNT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADNWW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADOC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADOCR',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADOCW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADP',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADPT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADRT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADSE',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADSEW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADSK',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADTH',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADTHW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADTN',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADTX',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADUS',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADV',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADVM',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADVWW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADX',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'ADXN',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AE',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEAE',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEAEW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEE',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEF',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEFC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEG',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEHL',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEHR',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEI',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEIS',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEL',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEM',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEMD',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AENT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AENZ',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEO',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEON',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEP',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AER',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AES',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AESC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AESI',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEVA',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEY',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEYE',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AEZS',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFAR',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFARU',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFB',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFBI',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFCG',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFG',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFGB',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFGC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFGD',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFGE',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFIB',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFL',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFMD',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFRI',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFRIW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFRM',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFT',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AFYA',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AG',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AGAE',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AGBA',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'AGBAW',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_1.csv'},
#  {'ticker': 'A

#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_2.csv'},
#  {'ticker': 'BOSC',
#   'status': 'SUCCESSFUL',
#   'description': 'Data written to file stocks_data_2.csv'},
#  ...]

# %%
len(json_data)
# Out:
# 7115

# %%
sdf = pd.DataFrame(json_data)

# %%
sdf["file_name"] = sdf.description.str.extract('(stocks_data_[0-9]{1,2}.csv)')

# %%
result = sdf.groupby("file_name").apply(lambda x: set(x["ticker"].values.tolist())).reset_index(name='tickers_list')

# %%
result["sorted_tickers_list"] = result.tickers_list.sort_values().apply(lambda x: sorted(x))

# %%
result
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>file_name</th>
#       <th>tickers_list</th>
#       <th>sorted_tickers_list</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>stocks_data_1.csv</td>
#       <td>{AACT, ADVM, AMR, AIRS, ADOCW, ADEX, ALYA, API...</td>
#       <td>[A, AA, AAC, AACG, AACI, AACIW, AACT, AADI, AA...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>stocks_data_10.csv</td>
#       <td>{TWOA, TNP, SRT, SRI, SND, SPIR, SOHU, UCL, SO...</td>
#       <td>[SMTC, SMTI, SMWB, SMX, SMXWW, SN, SNA, SNAL, ...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>stocks_data_11.csv</td>
#       <td>{WTRG, VIPS, UUUU, YCBD, ZIONP, UTME, UZE, VOR...</td>
#       <td>[UDMY, UDR, UE, UEC, UEIC, UFAB, UFCS, UFI, UF...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>stocks_data_2.csv</td>
#       <td>{CFFS, CAPL, BUJAW, CBRE, BANR, BGXX, BZ, BSX,...</td>
#       <td>[BACA, BACK, BAER, BAERW, BAFN, BAH, BAK, BALL...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>stocks_data_3.csv</td>
#       <td>{CPSI, CYN, CMTG, CYT, CPHI, DISTW, CNSL, COO,...</td>
#       <td>[CIF, CIFR, CIFRW, CIG, CIGI, CII, CIK, CIM, C...</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>stocks_data_4.csv</td>
#       <td>{FHLT, ETWO, FERG, FPI, EXPE, ESQ, FIACW, ELDN...</td>
#       <td>[DXCM, DXF, DXLG, DXPE, DXR, DXYN, DY, DYAI, D...</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>stocks_data_5.csv</td>
#       <td>{HCDIZ, GDO, GILD, GLUE, HDSN, HROWM, IHIT, GS...</td>
#       <td>[GAB, GABC, GAIA, GAIN, GAINL, GAINN, GAINZ, G...</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>stocks_data_6.csv</td>
#       <td>{LOCL, LC, LSXMB, JMM, JT, JLS, JOE, IVCBW, LU...</td>
#       <td>[ILPT, IMAB, IMACW, IMAQ, IMAQR, IMAQW, IMAX, ...</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>stocks_data_7.csv</td>
#       <td>{NOA, MUJ, MSN, NFJ, NICK, MBI, MET, NKX, MTZ,...</td>
#       <td>[MASS, MAT, MATH, MATV, MATW, MATX, MAV, MAX, ...</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>stocks_data_8.csv</td>
#       <td>{PINE, PIRS, OMER, PCAR, PNM, OCG, OXLC, NVTA,...</td>
#       <td>[NRAC, NRACW, NRBO, NRC, NRDS, NRDY, NREF, NRG...</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>stocks_data_9.csv</td>
#       <td>{RVSB, SMBC, RCLF, SKYT, ROKU, RFACU, SM, SAGE...</td>
#       <td>[PRGO, PRGS, PRH, PRI, PRIM, PRK, PRLB, PRLD, ...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
result["ticker_list_len1"] = result["tickers_list"].apply(len)
result["ticker_list_len2"] = result["sorted_tickers_list"].apply(len)

# %%
result
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>file_name</th>
#       <th>tickers_list</th>
#       <th>sorted_tickers_list</th>
#       <th>ticker_list_len1</th>
#       <th>ticker_list_len2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>stocks_data_1.csv</td>
#       <td>{AACT, ADVM, AMR, AIRS, ADOCW, ADEX, ALYA, API...</td>
#       <td>[A, AA, AAC, AACG, AACI, AACIW, AACT, AADI, AA...</td>
#       <td>706</td>
#       <td>706</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>stocks_data_10.csv</td>
#       <td>{TWOA, TNP, SRT, SRI, SND, SPIR, SOHU, UCL, SO...</td>
#       <td>[SMTC, SMTI, SMWB, SMX, SMXWW, SN, SNA, SNAL, ...</td>
#       <td>615</td>
#       <td>615</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>stocks_data_11.csv</td>
#       <td>{WTRG, VIPS, UUUU, YCBD, ZIONP, UTME, UZE, VOR...</td>
#       <td>[UDMY, UDR, UE, UEC, UEIC, UFAB, UFCS, UFI, UF...</td>
#       <td>585</td>
#       <td>585</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>stocks_data_2.csv</td>
#       <td>{CFFS, CAPL, BUJAW, CBRE, BANR, BGXX, BZ, BSX,...</td>
#       <td>[BACA, BACK, BAER, BAERW, BAFN, BAH, BAK, BALL...</td>
#       <td>677</td>
#       <td>677</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>stocks_data_3.csv</td>
#       <td>{CPSI, CYN, CMTG, CYT, CPHI, DISTW, CNSL, COO,...</td>
#       <td>[CIF, CIFR, CIFRW, CIG, CIGI, CII, CIK, CIM, C...</td>
#       <td>624</td>
#       <td>624</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>stocks_data_4.csv</td>
#       <td>{FHLT, ETWO, FERG, FPI, EXPE, ESQ, FIACW, ELDN...</td>
#       <td>[DXCM, DXF, DXLG, DXPE, DXR, DXYN, DY, DYAI, D...</td>
#       <td>619</td>
#       <td>619</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>stocks_data_5.csv</td>
#       <td>{HCDIZ, GDO, GILD, GLUE, HDSN, HROWM, IHIT, GS...</td>
#       <td>[GAB, GABC, GAIA, GAIN, GAINL, GAINN, GAINZ, G...</td>
#       <td>653</td>
#       <td>653</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>stocks_data_6.csv</td>
#       <td>{LOCL, LC, LSXMB, JMM, JT, JLS, JOE, IVCBW, LU...</td>
#       <td>[ILPT, IMAB, IMACW, IMAQ, IMAQR, IMAQW, IMAX, ...</td>
#       <td>692</td>
#       <td>692</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>stocks_data_7.csv</td>
#       <td>{NOA, MUJ, MSN, NFJ, NICK, MBI, MET, NKX, MTZ,...</td>
#       <td>[MASS, MAT, MATH, MATV, MATW, MATX, MAV, MAX, ...</td>
#       <td>575</td>
#       <td>575</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>stocks_data_8.csv</td>
#       <td>{PINE, PIRS, OMER, PCAR, PNM, OCG, OXLC, NVTA,...</td>
#       <td>[NRAC, NRACW, NRBO, NRC, NRDS, NRDY, NREF, NRG...</td>
#       <td>639</td>
#       <td>639</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>stocks_data_9.csv</td>
#       <td>{RVSB, SMBC, RCLF, SKYT, ROKU, RFACU, SM, SAGE...</td>
#       <td>[PRGO, PRGS, PRH, PRI, PRIM, PRK, PRLB, PRLD, ...</td>
#       <td>720</td>
#       <td>720</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
result['ticker_list_str'] = [','.join(i) if isinstance(i, list) else i for i in result['sorted_tickers_list']]

# %%
result[["file_name", "ticker_list_str"]]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>file_name</th>
#       <th>ticker_list_str</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>stocks_data_1.csv</td>
#       <td>A,AA,AAC,AACG,AACI,AACIW,AACT,AADI,AAIC,AAIN,A...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>stocks_data_10.csv</td>
#       <td>SMTC,SMTI,SMWB,SMX,SMXWW,SN,SNA,SNAL,SNAP,SNAX...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>stocks_data_11.csv</td>
#       <td>UDMY,UDR,UE,UEC,UEIC,UFAB,UFCS,UFI,UFPI,UFPT,U...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>stocks_data_2.csv</td>
#       <td>BACA,BACK,BAER,BAERW,BAFN,BAH,BAK,BALL,BALY,BA...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>stocks_data_3.csv</td>
#       <td>CIF,CIFR,CIFRW,CIG,CIGI,CII,CIK,CIM,CINF,CING,...</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>stocks_data_4.csv</td>
#       <td>DXCM,DXF,DXLG,DXPE,DXR,DXYN,DY,DYAI,DYN,DYNT,D...</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>stocks_data_5.csv</td>
#       <td>GAB,GABC,GAIA,GAIN,GAINL,GAINN,GAINZ,GALT,GAM,...</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>stocks_data_6.csv</td>
#       <td>ILPT,IMAB,IMACW,IMAQ,IMAQR,IMAQW,IMAX,IMCC,IMC...</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>stocks_data_7.csv</td>
#       <td>MASS,MAT,MATH,MATV,MATW,MATX,MAV,MAX,MAXN,MAYS...</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>stocks_data_8.csv</td>
#       <td>NRAC,NRACW,NRBO,NRC,NRDS,NRDY,NREF,NRG,NRGV,NR...</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>stocks_data_9.csv</td>
#       <td>PRGO,PRGS,PRH,PRI,PRIM,PRK,PRLB,PRLD,PRLH,PRLH...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
result[["file_name", "ticker_list_str"]].to_html(index=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>file_name</th>\n      <th>ticker_list_str</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>stocks_data_1.csv</td>\n      <td>A,AA,AAC,AACG,AACI,AACIW,AACT,AADI,AAIC,AAIN,AAL,AAMC,AAME,AAN,AAOI,AAON,AAP,AAPL,AAT,AAU,AB,ABBV,ABCB,ABCL,ABCM,ABEO,ABEV,ABG,ABIO,ABL,ABLLW,ABLV,ABLVW,ABM,ABNB,ABOS,ABR,ABSI,ABT,ABUS,ABVC,AC,ACA,ACAB,ACABW,ACACU,ACACW,ACAD,ACAQ,ACAX,ACAXR,ACAXU,ACAXW,ACB,ACBA,ACBAW,ACCD,ACCO,ACDC,ACDCW,ACEL,ACER,ACET,ACGL,ACGLN,ACGLO,ACHC,ACHL,ACHR,ACHV,ACI,ACIC,ACIU,ACIW,ACLS,ACLX,ACM,ACMR,ACN,ACNB,ACNT,ACON,ACONW,ACOR,ACP,ACR,ACRE,ACRO,ACRS,ACRV,ACRX,ACST,ACT,ACTG,ACU,ACV,ACVA,ACXP,ADAG,ADAP,ADBE,ADC,ADCT,ADD,ADEA,ADER,ADERW,ADES,ADEX,ADI,ADIL,ADM,ADMA,ADMP,ADN,ADNT,ADNWW,ADOC,ADOCR,ADOCW,ADP,ADPT,ADRT,ADSE,ADSEW,ADSK,ADT,ADTH,ADTHW,ADTN,ADTX,ADUS,ADV,ADVM,ADVWW,ADX,ADXN,AE,AEAE,AEAEW,AEE,AEF,AEFC,AEG,AEHL,AEHR,AEI,AEIS,AEL,AEM,AEMD,AENT,AENZ,AEO,AEON,AEP,AER,AES,AESC,AESI,A
N,ARES,ARGD,ARGO,ARGX,ARHS,ARI,ARIS,ARIZ,ARIZR,ARIZW,ARKO,ARKOW,ARKR,ARL,ARLO,ARLP,ARMK,ARMP,AROC,AROW,ARQQ,ARQQW,ARQT,ARR,ARRW,ARRWW,ARRY,ARTE,ARTEW,ARTL,ARTLW,ARTNA,ARTW,ARVL,ARVN,ARW,ARWR,ARYD,ASA,ASAI,ASAN,ASB,ASBA,ASC,ASCA,ASCB,ASCBR,ASG,ASGI,ASGN,ASH,ASIX,ASLE,ASLN,ASM,ASMB,ASML,ASND,ASNS,ASO,ASPA,ASPAW,ASPI,ASPN,ASPS,ASR,ASRT,ASRV,ASST,ASTC,ASTE,ASTI,ASTL,ASTLW,ASTR,ASTS,ASTSW,ASUR,ASX,ASXC,ASYS,ATAI,ATAK,ATAKR,ATAKU,ATAKW,ATAQ,ATAT,ATCOL,ATEC,ATEK,ATEN,ATER,ATEX,ATGE,ATHA,ATHE,ATHM,ATHX,ATI,ATIF,ATIP,ATKR,ATLC,ATLCL,ATLCP,ATLO,ATLX,ATMC,ATMCR,ATMU,ATMV,ATMVR,ATMVU,ATNF,ATNFW,ATNI,ATNM,ATO,ATOM,ATOS,ATR,ATRA,ATRC,ATRI,ATRO,ATS,ATSG,ATUS,ATVI,ATXG,ATXI,ATXS,AU,AUB,AUBN,AUDC,AUGX,AUID,AULT,AUMN,AUPH,AUR,AURA,AUROW,AUST,AUTL,AUUD,AUUDW,AUVI,AUVIP,AVA,AVAH,AVAL,AVAV,AVB,AVD,AVDL,AVDX,AVGO,AVGR,AVHI,AVHIW,AVID,AVIR,AVK,AVNS,AVNT,AVNW,AVO,AVPT,AVPTW,AVRO,AVT,AVTA,AVTE,AVTR,AVTX,AVXL,AVY,AWF,AWH,AWI,AWIN,AWINW,AWK,AWP,AWR,AWRE,AWX,AX,AXDX,AXGN,AXL,AXLA,AXNX,AXON,AXP,AXR,AXS,AXSM,AXTA,AXTI,AY,AYI,AYRO,AYTU,AYX,AZ,AZEK,AZN,AZO,AZPN,AZTA,AZTR,AZUL,AZYO,AZZ,B,BA,BABA,BAC</td>\n    </tr>\n    <tr>\n      <td>stocks_data_10.csv</td>\n      <td>SMTC,SMTI,SMWB,SMX,SMXWW,SN,SNA,SNAL,SNAP,SNAX,SNAXW,SNBR,SNCE,SNCR,SNCRL,SNCY,SND,SNDA,SNDL,SNDR,SNDX,SNES,SNEX,SNFCA,SNGX,SNMP,SNN,SNOA,SNOW,SNPO,SNPS,SNPX,SNSE,SNT,SNTG,SNTI,SNV,SNX,SNY,SO,SOBR,SOFI,SOFO,SOHO,SOHOB,SOHON,SOHOO,SOHU,SOI,SOJC,SOJD,SOJE,SOL,SOLO,SON,SOND,SO ...

# %% [markdown]
# # Exercise T

# %% [markdown]
# ## Objective – A
#
# ### Tasks
#
#
# ### Inputs
#
# ### Outputs

# %% [markdown]
# # References

# %% [markdown]
# - https://www.datacamp.com/blog/60-python-projects-for-all-levels-expertise
