# %%
# %pip install pyspark pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyspark in c:\users\sachingupta07\appdata\roaming\python\python313\site-packages (4.0.0)
# Requirement already satisfied: pyarrow in c:\users\sachingupta07\appdata\roaming\python\python313\site-packages (21.0.0)
# Requirement already satisfied: py4j==0.10.9.9 in c:\users\sachingupta07\appdata\roaming\python\python313\site-packages (from pyspark) (0.10.9.9)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
                    .appName("PySarkExp1")\
                    .config("spark.jars", ".\\..\\..\\assets\\libs\\postgresql-42.7.7.jar") \
                    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://IN-5CD521BFR8:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySarkExp1</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://localhost:5432/retail") \
    .option("dbtable", "user_mgmt.users") \
    .option("user", "postgres") \
    .option("password", "sachin") \
    .option("driver", "org.postgresql.Driver") \
    .load()

# %%
df.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- fname: string (nullable = true)
#  |-- lname: string (nullable = true)
#  |-- cretaed_at: timestamp (nullable = true)

# %%
df.show()
# Out:
# +---+------+-----+-------------------+
# | id| fname|lname|         cretaed_at|
# +---+------+-----+-------------------+
# |  1|Sachin|Gupta|2025-07-22 00:00:00|
# +---+------+-----+-------------------+

# %%
# spark.stop()
